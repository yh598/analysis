# %%
# Potentially used: unstructured[local-inference]

# %%
# %pip install -U transformers 
# %pip install --upgrade sentence-transformers
# %pip install --upgrade mlflow
# %pip install --upgrade langchain
# %pip install --upgrade databricks-vectorsearch==0.45 
# %pip install --upgrade pycryptodome
# %pip install --upgrade accelerate
# %pip install --upgrade sacremoses
# %pip install --upgrade ninja
# %pip install --upgrade tiktoken
# %pip install --upgrade nltk
# %pip install --upgrade databricks
# %pip install --upgrade databricks-agents
# %pip install --upgrade databricks-feature-engineering==0.8.1a2
# %pip install --upgrade pypdf
# %pip install --upgrade langchain_community

dbutils.library.restartPython()

# %%
import nltk
nltk.download('punkt')
